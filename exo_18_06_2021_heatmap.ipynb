# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
mydata = pd.read_csv('./csv/house_pricing.csv')
mydata.head(10)
mydata.iloc[:,-15:]
# Out:
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0           61              0          0            0
# 1            298            0              0          0            0
# 2              0           42              0          0            0
# 3              0           35            272          0            0
# 4            192           84              0          0            0
# ...          ...          ...            ...        ...          ...
# 1455           0           40              0          0            0
# 1456         349            0              0          0            0
# 1457           0           60              0          0            0
# 1458         366            0            112          0            0
# 1459         736           68              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# ...

# %%
mydata.iloc[:,-27:].corr()
# Out:
#                TotRmsAbvGrd  Fireplaces  GarageYrBlt  GarageCars  GarageArea  \
# TotRmsAbvGrd       1.000000    0.326114     0.148112    0.362289    0.337822
# Fireplaces         0.326114    1.000000     0.046822    0.300789    0.269141
# GarageYrBlt        0.148112    0.046822     1.000000    0.588920    0.564567
# GarageCars         0.362289    0.300789     0.588920    1.000000    0.882475
# GarageArea         0.337822    0.269141     0.564567    0.882475    1.000000
# WoodDeckSF         0.165984    0.200019     0.224577    0.226342    0.224666
# OpenPorchSF        0.234192    0.169405     0.228425    0.213569    0.241435
# EnclosedPorch      0.004151   -0.024822    -0.297003   -0.151434   -0.121777
# 3SsnPorch         -0.006683    0.011257     0.023544    0.035765    0.035087
# ScreenPorch        0.059383    0.184530    -0.075418    0.050494    0.051412
# PoolArea           0.083757    0.095074    -0.014501    0.020934    0.061047
# ...

# %%
sb.heatmap(mydata.iloc[:,-27:].corr())
# Out:
# <AxesSubplot:>
